# %% [markdown]
# how to share an idea?
#
# - picture
# - evngraving
# - song
# - send it via telegraph
# - etc...
#
# what this things share in common?\
# how are this things different?
#
# common is that this things are all methods to communicate. the fundamental particle of communication is **information**
#
# **information** or passing information allows to share ideas
#
# **information** allows one mind to influence another
#
# we can characterize each object with its mass. we use scale for that. weight rocks, weight water, weight sand and etc. all objects share this characteristic known as **mass**
#
# but is there a scale for **information**? can we compare two books by their information? how to quantize **information**? information is measured by **entropy**.
#
# ```raw
# entropy(book) >> entropy(page from this book)
# ```
#
# entropy is measured in bits. the bit is just yes/no answer to some question
#
# **Q**: does information have a speed limit?
# **A**: if we look through physics, then yes, the limit is speed of light -- signals can't travel faster then speed of light. if we look through CS, the we can talk in context of **useful** information and **not useful** information (noise). and what is the most effective way to transfer some information?

# %% [markdown]
# if we look back at the human history, then we notice that there were no progress regarding instruments and tools. up until some event which happen ~50000 years ago: at this time we see a big spike in human inventions (more sophisticated instruments and complicated tools such as music instruments, hunting weapons and etc). the cause of such mind expansion is that humans understand how to communicate, the alphabet was inveted and ideas were shared further, out of bounds of one human live. the experience of one generation now can be shared for future generations enabling the experience and ideas accumulation!
